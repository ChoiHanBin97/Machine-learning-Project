# %%
import pandas as pd
from bs4 import BeautifulSoup
import requests
import os

# %%
base_dir = 'C:\\Users\\user\\Python(Jupyter)\\Work\\data'
excel_file = 'data_0909.xlsx'
excel_dir = os.path.join(base_dir, excel_file)

sheet = '1. 파일기준_업무데이터'
data = pd.read_excel(excel_dir, 
                     sheet_name = sheet, index_col = 1)
data.head()
# Out:
#    Unnamed: 0            목록명 BRM\n분류체계              키워드  \
# 1         NaN     중기예보자료(일간)      과학기술   동네예보@단기예보@중기예보
# 2         NaN  기상청_초단기예보(월간)      과학기술   동네예보,단기예보,중기예보
# 3         NaN  기상청_초단기예보(월간)      과학기술   동네예보,단기예보,중기예보
# 4         NaN  기상청_초단기실황(월간)      과학기술  동네예보,단기예보,초단기실황
# 5         NaN  기상청_초단기실황(월간)      과학기술  동네예보,단기예보,초단기실황
#
#                                             설명                  파일데이터명  \
# 1                기상청에서 과거에 발표한 중기예보 자료를 제공합니다.              중기예보자료(일간)
# 2   예보시점부터 6시간 이내에 대하여 행하는 예보로, 매시 30분에 발표합니다.             초단기예보자료(월간)
# 3   예보시점부터 6시간 이내에 대하여 행하는 예보로, 매시 30분에 발표합니다.  기상청_초단기예보(월간)_20200801
# 4  동네예보 구역(5km 해상도 격자)에 대한 대표  AWS 관측값을 제공합니다.             초단기실황자료(월간)
# 5  동네예보 구역(5km 해상도 격자)에 대한 대표  AWS 관측값을 제공합니다.  기상청_초단기실황(월간)_20200801
#
#   업데이트\n주기 이용허락범위    제공형태  데이터 행  ... 정보공개성 데이터 여부 점검\n(이미지/영상 포함)  \
# 1       일간  저작자표시  링크 데이터      1  ...                           적합
# ...
